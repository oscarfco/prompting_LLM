# %%
# !python3 /home/ahojel/ama/new_tasks/WSC_final.py \
        --run_zeroshot 0 --run_fewshot 0 --run_decomp 1 \
        --num_boost 3 --k_shot 3 --output_metrics_file /home/ahojel/ama/metrics_oscar.json \
        --client_connection http://127.0.0.1:5005 # use the port from above
# Out:
# {
#     "seed": 3,
#     "num_run": -1,
#     "k_shot": 3,
#     "num_boost": 3,
#     "boost_train_examples": 1000,
#     "output_metrics_file": "/home/ahojel/ama/metrics_oscar.json",
#     "save_dir": "/home/ahojel/ama_logs/final_runs/",
#     "run_decomp": 1,
#     "run_zeroshot": 0,
#     "run_fewshot": 0,
#     "run_zeroshot_decomp": 0,
#     "overwrite_boost_exs": 0,
#     "overwrite_data": 0,
#     "client_name": "huggingface",
#     "client_engine": null,
#     "client_connection": "http://127.0.0.1:5005",
#     "cache_connection": "/home/ahojel/manifest_log/final_runs.sqlite",
#     "overwrite_manifest": 0,
#     "augmentations_from": "none",
#     "use_extraction": 0,
#     "use_question": 0
# }
# Reading test data from /home/ahojel/ama_logs/final_runs/super_glue_wsc/data.feather
# Reading train data from /home/ahojel/ama_logs/final_runs/super_glue_wsc/train_data.feather
# Test Data Size: 104
# Train Data Size: 554
# Model name: EleutherAI_gpt-neo-1.3B
# ...
